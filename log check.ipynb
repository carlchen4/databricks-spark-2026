# %% [markdown]
# Step 1 DESCRIBE HISTORY databricks_carltest.default.bank_accounts_source;
# Step 2 找某个 version
# Step 3 SELECT * FROM table VERSION AS OF 12;
# Step 4（必要时）才去看 _delta_log JSON

# %%
# %sql
DESCRIBE HISTORY databricks_carltest.default.bank_accounts_source;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
DESCRIBE DETAIL databricks_carltest.default.bank_accounts_source;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT * FROM bank_accounts_source VERSION AS OF 12;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
